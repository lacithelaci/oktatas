# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_sample_image
import PIL

# %%
im = PIL.Image.open('./datasets/image.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400>

# %%
data = np.asarray(im) # minden egyes pixelhez visszaadja a színkódot
data
# Out:
# array([[[ 48, 115, 193],
#         [ 48, 115, 193],
#         [ 49, 116, 194],
#         ...,
#         [  0,  82, 164],
#         [  0,  82, 164],
#         [  0,  82, 164]],
#
#        [[ 48, 115, 193],
#         [ 48, 115, 193],
#         [ 49, 116, 194],
#         ...,
#         [  0,  82, 164],
#         [  0,  82, 164],
#         [  0,  82, 164]],
#
#        [[ 47, 114, 192],
#         [ 48, 115, 193],
#         [ 49, 116, 194],
#         ...,
#         [  1,  83, 165],
#         [  0,  82, 164],
#         [  0,  82, 164]],
#
#        ...,
#
#        [[  9,   3,   3],
#         [  9,   3,   3],
#         [ 21,  15,  15],
#         ...,
#         [221, 222, 227],
#         [223, 224, 229],
#         [225, 226, 231]],
#
#        [[ 12,   6,   6],
#         [  4,   0,   0],
#         [  4,   0,   0],
#         ...,
#         [216, 216, 224],
#         [214, 217, 224],
#         [214, 217, 224]],
#
#        [[ 11,   5,   5],
#         [ 26,  20,  20],
#         [ 16,  10,  10],
#         ...,
#         [215, 215, 223],
#         [212, 215, 222],
#         [210, 213, 220]]], shape=(400, 640, 3), dtype=uint8)

# %%
data.shape
# Out:
# (400, 640, 3)

# %%
data = data.reshape((-1,3))

# %%
data.shape
# Out:
# (256000, 3)

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:,0], data[:,1], data[:,2], marker='o', s=5)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(data);

# %%
def plot_result_3d(kmeans):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter3D(data[:,0],data[:,1],data[:,2],c=kmeans.labels_, marker='+')
    ax.set_title(str(kmeans.n_clusters) + ' Cluster(s)')
plot_result_3d(kmeans)

# %%
newimg = kmeans.cluster_centers_[kmeans.labels_]
newimg.shape
# Out:
# (256000, 3)

# %%
newimg = newimg.reshape((400,640,3)).astype('uint8')

# %%
PIL.Image.fromarray(newimg)
# Out:
# <PIL.Image.Image image mode=RGB size=640x400>
